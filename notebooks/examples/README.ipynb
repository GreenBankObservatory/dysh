# %% [markdown]
# # How to read notebooks
#
# Documentation can be found in https://dysh.readthedocs.io - including pointers to the notebooks listed below.

# %% [markdown]
# ## Concepts:
#
# These are in "Recipes"
#
# 1. [Data IO](./dataIO.ipynb) :  saving data, SDFITS and FITS spectra
# 2. [Modifying Metadata](./metadata_management)
# 3. [Selecting data](./selection.ipynb)
# 5. [Flagging](.flagging)

# %% [markdown]
# ## Procedures
#
# These are mostly in "Tutorials"
#
# 1. [Position Switched observations](./positionswitch.ipynb)
# 2. hi_survey
# 3. calseq
# 4. frequencyswitch
# 5. nodding
# 6. on_the_fly
# 7. subbeamnod
# 8. vane

# %% [markdown]
# ## Advanced
#
# These are also in "Recipes"
#
# 1. velocity_frames
# 2. using_spectral_weights
# 3. repeated_scans
# 4. merge_sdfits
# 5. line_search
# 6. gauss_fit
# 7. apeff_surferr
# 8. align_spectra
# 9. quality
# 10. smoothing
# 11. staff_training
# 12. custom_baseline

# %% [markdown]
# ## notebooks alphabetical
# ```
# align_spectra
# apeff_surferr
# calseq
# custom_baseline
# dataIO
#
# flagging
# frequencyswitch
# gauss_fit
# hi_survey
# line_search
#
# merge_sdfits
# metadata_management
# nodding                          logger,   radiometer is bad
# on_the_fly
# positionswitch
#
# quality
# repeated_scans
# selection
# smoothing
# staff_training
#
# subbeamnod
# using_spectral_weights
# vane
# velocity_frames
# ```
