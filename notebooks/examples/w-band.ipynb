# %% [markdown]
# # GBT W-Band Data Reduction
#
# This tutorial goes through the data reduction for observations taken with the W-Band receiver on the GBT. This receiver has two feeds (beams) and covers the frequency range from 67 to 92 GHz, and, unlike most of the GBT receivers, it does not have noise diodes for calibration. Instead it uses a wheel to put hot and cold loads in front of the receiver, in what we call a calibration sequence (calseq).
#
# The data in this example contains observations of M82 using the [Nod observing procedure](https://gbtdocs.readthedocs.io/en/latest/references/software/scheduling-blocks.html#astrid_commands.Nod). The frequency range covered by this receiver cannot be observed in a single setup, so it is split into four setups.
#
# ## Loading Modules
# We start by loading the modules we will use for the data reduction.
#
# For display purposes, we use the static (non-interactive) matplotlib backend in this tutorial. However, you can tell `matplotlib` to use the `ipympl` backend to enable interactive plots. This is only needed if working on jupyter lab or notebook.

# %%
# Set interactive plots in jupyter.
#%matplotlib ipympl

# These are required for the data reduction.
from dysh.fits import GBTFITSLoad
from dysh.log import init_logging
from astropy import units as u
import numpy as np
import matplotlib.pyplot as plt

# These ones are only used to download and unpack the data.
import tarfile
from pathlib import Path
from dysh.util.download import from_url

# %% [markdown]
# ## Data Retrieval
#
# Download and unpack the example SDFITS data, if necessary.

# %%
url = "http://www.gb.nrao.edu/dysh/example_data/nod-W/data/AGBT15B_244_07.raw.vegas.tar.gz"
savepath = Path.cwd() / "data"
filename = from_url(url, savepath)
print(filename)
# Unpack.
with tarfile.open(filename) as targz:
    targz.extractall('./data/') 
    targz.close()
# Out:
# /home/sandboxes/psalas/Dysh/dysh/notebooks/examples/data/AGBT15B_244_07.raw.vegas.tar.gz

# %% [markdown]
# ## Data Loading
#
# Next, we use `GBTFITSLoad` to load the data, and then its `summary` method to inspect its contents.

# %%
sdfits = GBTFITSLoad("./data/AGBT15B_244_07.raw.vegas")
sdfits.summary()
# Out:
# Flags were created from existing flag files. Use GBTFITSLoad.flags.show() to see them.
# Loaded 8 FITS files
#     SCAN OBJECT VELOCITY    PROC  PROCSEQN RESTFREQ DOPFREQ # IF # POL # INT  \
# 0    130    M82      0.0  CALSEQ         1   87.645    86.4    4     2    41
# 1    131    M82      0.0     Nod         1   87.645    86.4    4     2    61
# 2    132    M82      0.0     Nod         2   87.645    86.4    4     2    61
# 3    133    M82      0.0     Nod         1   87.645    86.4    4     2    61
# 4    134    M82      0.0     Nod         2   87.645    86.4    4     2    61
# 5    135    M82      0.0     Nod         1   87.645    86.4    4     2    61
# 6    136    M82      0.0     Nod         2   87.645    86.4    4     2    61
# 7    137    M82      0.0     Nod         1   87.645    86.4    4     2    61
# 8    138    M82      0.0     Nod         2   87.645    86.4    4     2    61
# 9    139    M82      0.0     Nod         1   87.645    86.4    4     2    61
# 10   140    M82      0.0     Nod         2   87.645    86.4    4     2    61
# 11   141    M82      0.0  CALSEQ         1   87.645    86.4    4     2    41
#
#    # FEED     AZIMUTH   ELEVATIO
# 0       2  334.375845  46.552969
# 1       2  334.340511  46.455481
# 2       2  334.420688  46.356491
# 3       2  334.270943  46.255965
# 4       2  334.352313  46.156723
# 5       2  334.205169   46.05736
# 6       2  334.287644  45.957891
# 7       2  334.142569  45.858239
# 8       2  334.225833  45.757117
# 9       2  334.082225  45.655873
# 10      2  334.167154  45.555955
# 11      2  334.027735  45.461716

# %% [markdown]
# There are 12 scans in this dataset. Using four spectral windows, two feeds and two polarizations. There are two calseq procedures at the start and end of the observation, and in between a series of five Nod observations.
#
# ## Data Reduction
#
# ### System Temperature
#
# To calibrate the data we need to know the system temperature during the observations. We use the `GBTFITSLoad.calseq` function to derive the system temperature from the calseq observations. We do this for both feeds, the four spectral windows, and both polarizations.

# %%
fdnums = sdfits.udata("FDNUM") # Feeds.
ifnums = sdfits.udata("IFNUM") # Spectral windows.
plnums = sdfits.udata("PLNUM") # Polarizations. 
cscans = [130, 141] # calseq scan numbers.

# Create an array to store the system temperature for each combination.
tsys = np.empty((len(cscans), len(fdnums), len(plnums), len(ifnums)), dtype=float)

# Loop over the combinations.
for s,scan in enumerate(cscans):
    for f,fdnum in enumerate(fdnums):
        for p,plnum in enumerate(plnums):
            for i,ifnum in enumerate(ifnums):
                tsys[s,f,p,i], _ = sdfits.calseq(scan=scan, fdnum=fdnum, plnum=plnum, ifnum=ifnum)

# %% [markdown]
# We check how much the system temperature changed between the start and end of the observations. We evaluate this in the form of a percentage relative to the time average of the system temperature.

# %%
np.diff(tsys, axis=0)/np.mean(tsys, axis=0)*100
# Out:
# array([[[[0.4283614 , 0.54354858, 0.17681944, 0.09606006],
#          [0.27810328, 0.22292022, 0.21663116, 0.19301117]],
#
#         [[0.45624908, 0.39582222, 0.41662913, 0.33675926],
#          [0.38325336, 0.30534935, 0.27691407, 0.29814596]]]])

# %% [markdown]
# From the above we see that the system temperature changed by less than 0.6%. We will take the mean of the system temperatures as a function of time for the calibration.

# %%
tsys = np.mean(tsys, axis=0)

# %% [markdown]
# ### Nod Calibration
#
# Now we proceed to calibrate the Nod observations. We will use a similar startegy as before, looping over the possible combinations of spectral window, polarization and feeds. However, we will time average the calibrated data, so in the end we will only have one spectrum per spectral window and polarization. Since the data is observed using Nod, the processing will combine the spectra for both beams. The scans we calibrate are all the Nod scans, but we only need to provide the number of one of them per pair, since `dysh` will automatically figure out which scan is the corresponding pair.
#
# The spectra we will save are `Spectrum` objects, so we set the data type, `dtype`, of the array to `object`.
#
# In the call to `GBTFITSLoad.getnod` we must provide a value for the system temperature, one for each beam. In this case, the system temperature for each beam must be in a separate list, like `[[120],[160]]`, where the first feed would use a system temperature of 120 K and the second 160 K. So we take the two system temperatures an pack them into a list or lists before calling the calibration function `getnod`.

# %%
nod_ta = np.empty((len(plnums), len(ifnums)), dtype=object)
nod_scans = [131, 133, 135, 137, 139]

for p,plnum in enumerate(plnums):
    for i,ifnum in enumerate(ifnums):
        # Extract the system temperature for both feeds for this polarization and spectral window.
        t_sys = [[t] for t in tsys[:,p,i]]
        # Call the calibration function.
        nod_ta[p,i] = sdfits.getnod(scan=nod_scans, ifnum=ifnum, plnum=plnum, t_sys=t_sys).timeaverage()

# %% [markdown]
# ### Inspecting the Calibrated Data
#
# Now that we have calibrated our observations, we plot the results to view the calibrated data. We start by plotting things using the built-in plotting functions for `Spectrum` objects, then we proceed to plot the spectra using custom `matplotlib` commands.
#
# In the following cells we will plot one polarization for the individual spectral windows.

# %%
nod_ta[0,0].plot()

# %%
nod_ta[0,1].plot()

# %%
nod_ta[0,2].plot()

# %%
nod_ta[0,3].plot()

# %% [markdown]
# Now we will plot all of the spectral windows in a single figure. Since we are using `matplotlib` and it does not know about the units, we must set the labels by hand.

# %%
fig = plt.figure(dpi=150)
fig.suptitle("PLNUM=0")
ax = fig.add_subplot(111)
for t in nod_ta[0]:
    # We need to apply the mask to the data, otherwise it will show as zeros.
    flux = np.ma.masked_where(t.mask, t.flux)
    # Use an alpha of less than one to see the overlapping regions.
    ax.plot(t.spectral_axis.to("GHz"), flux, alpha=0.5, label=f"IFNUM={t.meta['IFNUM']}")
# Show a legend.
ax.legend()
# Limit y-range to focus on data.
ax.set_ylim(0, 0.4)
# Set axis labels by hand.
ax.set_xlabel("Frequency (GHz)")
ax.set_ylabel(f"Antenna temperature ({t.flux.unit})");

# %%
fig = plt.figure(dpi=150)
fig.suptitle("PLNUM=1")
ax = fig.add_subplot(111)
for t in nod_ta[1]:
    # We need to apply the mask to the data, otherwise it will show as zeros.
    flux = np.ma.masked_where(t.mask, t.flux)
    # Use an alpha of less than one to see the overlapping regions.
    ax.plot(t.spectral_axis.to("GHz"), flux, alpha=0.5, label=f"IFNUM={t.meta['IFNUM']}")
# Show a legend.
ax.legend()
# Limit y-range to focus on data.
ax.set_ylim(0, 0.4)
# Set axis labels by hand.
ax.set_xlabel("Frequency (GHz)")
ax.set_ylabel(f"Antenna temperature ({t.flux.unit})");

# %% [markdown]
# We see that spectral windows 1, 2 and 3 have strong detections of spectral lines. We focus on these spectral windows from now on.

# %%
nod_ta_lines = nod_ta[:,[1,2,3]]

# %% [markdown]
# ### Baseline Subtraction
#
# Now we proceed to remove the baseline from the spectral windows. For this, we will ignore the channels where we see the spectral lines. The ranges we will ignore are: ifnum=1 from 87.2 to 87.3 GHz, ifnum=2 from 88.5 to 88.7 GHz, and for ifnum=3 from 88.5 to 88.7 and 89 to 89.23 GHz. We will also ignore the first and last 500 channels of each spectra. The exclusion regions must be specified as a list of tuples, like `[(1,10),(50,100)]`, and they can include units as well, however, only one unit per exclusion region is supported. We use an order 15 polynomial as the baseline model. This is a high order, but it captures most of the structure on the spectra for both polarizations.

# %%
# Define baseline parameters.
order = 15
model = "poly"
edge = 500
exclude = {1: [(nod_ta_lines[0,0].spectral_axis.quantity.min().to("GHz"), 
                nod_ta_lines[0,0].spectral_axis.quantity[edge].to("GHz")),
               (87.2*u.GHz, 87.3*u.GHz),
               (nod_ta_lines[0,0].spectral_axis.quantity[-edge].to("GHz"), 
                nod_ta_lines[0,0].spectral_axis.quantity.max().to("GHz")),
              ],
           2: [(nod_ta_lines[0,1].spectral_axis.quantity.min().to("GHz"), 
                nod_ta_lines[0,1].spectral_axis.quantity[edge].to("GHz")),
               (88.5*u.GHz, 88.65*u.GHz), 
               (nod_ta_lines[0,1].spectral_axis.quantity[-edge].to("GHz"), 
                nod_ta_lines[0,1].spectral_axis.quantity.max().to("GHz"))
              ],
           3: [(nod_ta_lines[0,2].spectral_axis.quantity.min().to("GHz"), 
                nod_ta_lines[0,2].spectral_axis.quantity[edge].to("GHz")),
               (88.5*u.GHz, 88.7*u.GHz), 
               (89*u.GHz, 89.23*u.GHz),
               (nod_ta_lines[0,2].spectral_axis.quantity[-edge].to("GHz"), 
                nod_ta_lines[0,2].spectral_axis.quantity.max().to("GHz"))
              ],
          }

# %%
# Loop over spectra and remove the baseline.
for nod_ta_lines_p in nod_ta_lines:
    for spec in nod_ta_lines_p:
        spec.baseline(order, model=model, exclude=exclude[spec.meta["IFNUM"]], remove=True)

# %% [markdown]
# Plot again after removing the baseline.

# %%
fig = plt.figure(dpi=150)
fig.suptitle("PLNUM=0")
ax = fig.add_subplot(111)
for t in nod_ta_lines[0]:
    # We need to apply the mask to the data, otherwise it will show as zeros.
    flux = np.ma.masked_where(t.mask, t.flux)
    # Use an alpha of less than one to see the overlapping regions.
    ax.plot(t.spectral_axis.to("GHz"), flux, alpha=0.5, label=f"IFNUM={t.meta['IFNUM']}")
# Show a legend.
ax.legend()
# Limit y-range to focus on data.
ax.set_ylim(-0.4, 0.4)
# Set axis labels by hand.
ax.set_xlabel("Frequency (GHz)")
ax.set_ylabel(f"Antenna temperature ({t.flux.unit})");

# %%
fig = plt.figure(dpi=150)
fig.suptitle("PLNUM=1")
ax = fig.add_subplot(111)
for t in nod_ta_lines[1]:
    # We need to apply the mask to the data, otherwise it will show as zeros.
    flux = np.ma.masked_where(t.mask, t.flux)
    # Use an alpha of less than one to see the overlapping regions.
    ax.plot(t.spectral_axis.to("GHz"), flux, alpha=0.5, label=f"IFNUM={t.meta['IFNUM']}")
# Show a legend.
ax.legend()
# Limit y-range to focus on data.
ax.set_ylim(-0.4, 0.4)
# Set axis labels by hand.
ax.set_xlabel("Frequency (GHz)")
ax.set_ylabel(f"Antenna temperature ({t.flux.unit})");

# %% [markdown]
# ### Correcting for Atmospheric Opacity
#
# So far the calibrated data has been in the antenna temperature scale, which does not take into account the effects of the atmosphere in the temperature scale. To calibrate taking these effects into account we need to specify an opacity and request a different brightness scale. The scales currently supported by `dysh` are "Ta*" (antenna temperature corrected for atmospheric opacity) and "Jy" (flux density). More details about the calibration can be found in the articles by [Kutner & Ulich (1981)](https://ui.adsabs.harvard.edu/abs/1981ApJ...250..341K/abstract), [Kramer (1997)](https://publicwiki.iram.es/CalibrationPapers?action=AttachFile&do=view&target=kramer_1997_cali_rep.pdf) and [Frayer et al. (2019)](https://library.nrao.edu/public/memos/gbt/GBT_302.pdf).
#
# If you are working inside the GBO network, in one of the [GBO data reduction hosts](https://greenbankobservatory.org/portal/gbt/processing/), then you can use the convenience functions incorporated into `dysh` to retrieve atmospheric opacity.
#
# ```Python
# from dysh.util.weatherforecast import GBTWeatherForecast
# gbwf = GBTWeatherForecast()
# spec = nod_ta_lines[0,0]
# mjd, freq, tau = gbwf.fetch(vartype="Opacity",
#                             specval=spec.spectral_axis.quantity.mean(),
#                             mjd=spec.obstime.mjd
#                            )
# ```
#
# If you are not working at GBO, then you can follow [these instructions](https://gbtdocs.readthedocs.io/en/latest/how-tos/data_reduction/calculate_opacity.html) to figure out the opacity.
#
# If you do not have access to the GBO computing environment, you can use the [NRAO helpdesk](https://help.nrao.edu/) to ask for opacity values for the GBT. Please specify the dates (accurate to the hour) and frequencies for which you require opacities.
#
# Here we will use the following values, in a dictionary with keys corresponding to the spectral window (IFNUM).

# %%
tau = {0: 6.28488304e-02,
       1: 5.99070412e-02,
       2: 5.73315943e-02,
       3: 5.51805677e-02
      }

# %% [markdown]
# We repeat the calibration specifying the opacity with the `zenith_opacity` argument and requesting that the data be calibrated to "Ta*" with the `bunit` argument.

# %%
nod_ta_star = np.empty((len(plnums), len(ifnums)), dtype=object)
nod_scans = [131, 133, 135, 137, 139]

for p,plnum in enumerate(plnums):
    for i,ifnum in enumerate(ifnums):
        # Extract the system temperature for both feeds for this polarization and spectral window.
        t_sys = [[t] for t in tsys[:,p,i]]
        # Call the calibration function.
        nod_ta_star[p,i] = sdfits.getnod(scan=nod_scans, ifnum=ifnum, plnum=plnum, 
                                         t_sys=t_sys, 
                                         zenith_opacity=tau[ifnum],
                                         bunit="Ta*"
                                        ).timeaverage()

# %% [markdown]
# Note: there is a known bug, where the y-axis will still show antenna temperature, $T_{A}$, as the y-axis label even after calibrating to $T_{A}^{*}$. The bug is being tracked [here](https://github.com/GreenBankObservatory/dysh/issues/596). For now, we specify the y-axis label by hand:

# %%
nod_ta_star[0,0].plot(ylabel=r"$T_{A}^{*}$ (K)")

# %% [markdown]
# Now we repeat the baseline subtraction on the spectral windows that show emission lines.

# %%
nod_ta_star_lines = nod_ta_star[:,[1,2,3]]
for nod_ta_star_lines_p in nod_ta_star_lines:
    for spec in nod_ta_star_lines_p:
        spec.baseline(order, model=model, exclude=exclude[spec.meta["IFNUM"]], remove=True)

# %%
fig = plt.figure(dpi=150)
fig.suptitle("PLNUM=0")
ax = fig.add_subplot(111)
for t in nod_ta_star_lines[0]:
    # We need to apply the mask to the data, otherwise it will show as zeros.
    flux = np.ma.masked_where(t.mask, t.flux)
    # Use an alpha of less than one to see the overlapping regions.
    ax.plot(t.spectral_axis.to("GHz"), flux, alpha=0.5, label=f"IFNUM={t.meta['IFNUM']}")
# Show a legend.
ax.legend()
# Limit y-range to focus on data.
ax.set_ylim(-0.4, 0.9)
# Set axis labels by hand.
ax.set_xlabel("Frequency (GHz)")
ax.set_ylabel(fr"$T_{{A}}^{{*}}$ ({t.flux.unit})");

# %%
fig = plt.figure(dpi=150)
fig.suptitle("PLNUM=1")
ax = fig.add_subplot(111)
for t in nod_ta_star_lines[1]:
    # We need to apply the mask to the data, otherwise it will show as zeros.
    flux = np.ma.masked_where(t.mask, t.flux)
    # Use an alpha of less than one to see the overlapping regions.
    ax.plot(t.spectral_axis.to("GHz"), flux, alpha=0.5, label=f"IFNUM={t.meta['IFNUM']}")
# Show a legend.
ax.legend()
# Limit y-range to focus on data.
ax.set_ylim(-0.4, 0.9)
# Set axis labels by hand.
ax.set_xlabel("Frequency (GHz)")
ax.set_ylabel(fr"$T_{{A}}^{{*}}$ ({t.flux.unit})");

# %% [markdown]
# ### Polarization Average
#
# We are now in a position to average the polarizations. This reduces the noise in the spectra. To average spectra we use the `Spectrum.average` function. It takes as input a list of other `Spectrum` objects. It does not check if the spectra are repeated.
#
# We create a new array `ta_star_pol_ave` where we store the polarization averages, and then we loop over the spectra averaging polarizations.

# %%
ta_star_pol_ave = np.empty(nod_ta_star_lines.shape[1], dtype=object)

for i in range(nod_ta_star_lines.shape[1]):
    ta_star_pol_ave[i] = nod_ta_star_lines[0,i].average(nod_ta_star_lines[1,i])

# %% [markdown]
# Plot the polarization averages.

# %%
fig = plt.figure(dpi=150)
fig.suptitle("Polarization Average")
ax = fig.add_subplot(111)
for t in ta_star_pol_ave:
    # We need to apply the mask to the data, otherwise it will show as zeros.
    flux = np.ma.masked_where(t.mask, t.flux)
    # Use an alpha of less than one to see the overlapping regions.
    ax.plot(t.spectral_axis.to("GHz"), flux, alpha=0.5, label=f"IFNUM={t.meta['IFNUM']}")
# Show a legend.
ax.legend()
# Limit y-range to focus on data.
ax.set_ylim(-0.4, 0.9)
# Set axis labels by hand.
ax.set_xlabel("Frequency (GHz)")
ax.set_ylabel(fr"$T_{{A}}^{{*}}$ ({t.flux.unit})");

# %% [markdown]
# ## Saving the Calibrated Spectra
#
# Now that we have calibrated our data correcting for atmospheric opacity we save it to FITS files.
#
# First, we create an output directory in the current directory.

# %%
products_path = Path.cwd() / "output"
products_path.mkdir(exist_ok=True)

# %% [markdown]
# Now loop over spectral windows saving the data.

# %%
for spec in ta_star_pol_ave:
    fnm_out = products_path / f"M82_ifnum_{spec.meta['IFNUM']}_polavg.fits"
    spec.write(fnm_out, format="fits", overwrite=True)

# %% [markdown]
# The data is now in FITS tables.

# %% [markdown]
# ## Loading the Calibrated Spectra
#
# Now that we have saved the calibrated spectra to FITS files, we can read it back in. There are multiple ways of reading back FITS spectra, here we show how to using `astropy.io.fits` (raw reading).
#
# To read the file we use the `fits.open` function.

# %%
from astropy.io import fits

# %%
hdu = fits.open(products_path / "M82_ifnum_1_polavg.fits")

# %%
hdu
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7fabd85e7fa0>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x7fabd85e4ca0>]

# %% [markdown]
# The data is in the second element of the opened file. We can retrieve the header and table data using the `header` and `data` properties.

# %%
header = hdu[1].header
data = hdu[1].data
hdu.close() # Close the file for now.

# %% [markdown]
# The header contains all the meta data from the `Spectrum`, as well as the data reduction history.

# %%
header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   48 / length of dimension 1
# NAXIS2  =                16384 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    6 / number of table fields
# TTYPE1  = 'spectral_axis'
# TFORM1  = 'D       '
# TUNIT1  = 'Hz      '
# TTYPE2  = 'flux    '
# TFORM2  = 'D       '
# TUNIT2  = 'K       '
# TTYPE3  = 'uncertainty'
# TFORM3  = 'D       '
# TTYPE4  = 'weight  '
# TFORM4  = 'D       '
# TTYPE5  = 'mask    '
# TFORM5  = 'K       '
# TTYPE6  = 'baseline'
# TFORM6  = 'D       '
# TUNIT6  = 'K       '
# OBJECT  = 'M82     '
# BANDWID =         1500000000.0
# DATE-OBS= '2017-02-04T10:11:43.00'
# DURATION=           0.99964243
# EXPOSURE=    596.6543863195149
# TSYS    =    105.2230347369145
# CTYPE1  = 'FREQ-OBS'
# CRVAL1  =        87228489084.0
# CRPIX1  =               8193.0
# CDELT1  =         91552.734375
# CTYPE2  = 'RA      '
# CRVAL2  =   148.93912370729376
# CTYPE3  = 'DEC     '
# CRVAL3  =    69.63322331544632
# CRVAL4  =                   -6
# OBSERVER= 'Dom Pesce'
# OBSID   = 'unknown '
# SCAN    =                  131
# OBSMODE = 'Nod:NONE:TPNOCAL'
# FRONTEND= 'Rcvr68_92'
# TCAL    =                  1.0
# VELDEF  = 'OPTI-BAR'
# VFRAME  =    5241.161782043649
# RVSYS   =    5241.161782043649
# OBSFREQ =        87228489084.0
# LST     =    49886.57916905915
# AZIMUTH =    334.4132429832569
# ELEVATIO=   46.497692750558066
# TAMBIENT=               261.45
# PRESSURE=    699.2300098716685
# HUMIDITY=                0.691
# RESTFREQ=        87230000000.0
# FREQRES =         91552.734375
# EQUINOX =               2000.0
# RADESYS = 'FK5     '
# TRGTLONG=    148.9695833333333
# TRGTLAT =    69.67944444444444
# SAMPLER = 'B2_0    '
# FEED    =                    1
# SRFEED  =                    0
# FEEDXOFF=                  0.0
# FEEDEOFF=                  0.0
# HIERARCH SUBREF_STATE = 1
# SIDEBAND= 'U       '
# PROCSEQN=                    1
# PROCSIZE=                    2
# PROCSCAN= 'BEAM1   '
# PROCTYPE= 'SIMPLE  '
# LASTON  =                  131
# LASTOFF =                    0
# HIERARCH TIMESTAMP = '2017_02_04_10:11:43'
# QD_XEL  = -0.00172575483707228
# QD_EL   = 0.001033652915095047
# QD_BAD  =                    0
# HIERARCH QD_METHOD = 'A       '
# VELOCITY=                  0.0
# DOPFREQ =        86400000000.0
# ADCSAMPF=         3000000000.0
# VSPDELT =                512.0
# VSPRVAL =                 16.0
# VSPRPIX =               8193.0
# SIG     = 'T       '
# CAL     = 'F       '
# CALTYPE = 'LOW     '
# TWARM   =         263.18359375
# TCOLD   =           18.5546875
# HIERARCH CALPOSITION = 'Observing'
# IFNUM   =                    1
# PLNUM   =                    0
# FDNUM   =                    0
# HDU     =                    1
# BINTABLE=                    0
# ROW     =                   83
# SIMPLE  =                    T
# EXTEND  =                    T
# DATE    = '2024-07-12T13:16:23'
# ORIGIN  = 'NRAO Green Bank'
# TELESCOP= 'NRAO_GBT'
# INSTRUME= 'VEGAS   '
# SDFITVER= 'sdfits ver1.22'
# FITSVER = '1.9     '
# CTYPE4  = 'STOKES  '
# PROJID  = 'AGBT15B_244_07'
# BACKEND = 'VEGAS   '
# SITELONG=            -79.83983
# SITELAT =             38.43312
# SITEELEV=              824.595
# EXTNAME = 'SINGLE DISH'
# HIERARCH FITSINDEX = 1
# PROC    = 'Nod     '
# OBSTYPE = 'NONE    '
# HIERARCH SUBOBSMODE = 'TPNOCAL '
# CUNIT1  = 'Hz      '
# CUNIT2  = 'deg     '
# CUNIT3  = 'deg     '
# RESTFRQ =        87230000000.0
# BUNIT   = 'K       '
# MEANTSYS=   105.01744133557179
# WTTSYS  =    105.0174413355718
# HISTORY 2025-05-27T12:17:35 - This GBTFITSLoad encapsulates the files: ['data/AG
# HISTORY BT15B_244_07.raw.vegas/AGBT15B_244_07.raw.vegas.A.fits', 'data/AGBT15B_2
# HISTORY 44_07.raw.vegas/AGBT15B_244_07.raw.vegas.B.fits', 'data/AGBT15B_244_07.r
# HISTORY aw.vegas/AGBT15B_244_07.raw.vegas.C.fits', 'data/AGBT15B_244_07.raw.vega
# HISTORY s/AGBT15B_244_07.raw.vegas.D.fits', 'data/AGBT15B_244_07.raw.vegas/AGBT1
# HISTORY 5B_244_07.raw.vegas.E.fits', 'data/AGBT15B_244_07.raw.vegas/AGBT15B_244_
# HISTORY 07.raw.vegas.F.fits', 'data/AGBT15B_244_07.raw.vegas/AGBT15B_244_07.raw.
# HISTORY vegas.G.fits', 'data/AGBT15B_244_07.raw.vegas/AGBT15B_244_07.raw.vegas.H
# HISTORY .fits']
# HISTORY 2025-05-27T12:17:40 - Project ID: AGBT15B_244_07
# HISTORY 2025-05-27T12:17:40-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.__init__(./data/AGBT15B_244_07.raw.vegas,)
# HISTORY 2025-05-27T12:17:44-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:17:48-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:17:51-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:17:55-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:17:58-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:02-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:05-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:08-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:12-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:15-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:19-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:22-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:25-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:29-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:32-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:35-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:39-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:42-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:45-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:49-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:52-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:55-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:18:59-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:02-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:05-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:09-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:12-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:16-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:19-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:22-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:26-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:29-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:32-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:36-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:39-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:43-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:46-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:49-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:53-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:56-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:19:59-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:03-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:06-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:09-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:13-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:16-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:20-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:23-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:26-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:30-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:33-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:36-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:40-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:43-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:46-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:50-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:53-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:20:56-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:00-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:03-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:07-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:10-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:13-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:17-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:20-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:24-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:27-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:31-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:34-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:38-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:41-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:45-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:48-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:51-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:55-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:21:58-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:01-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:05-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:08-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:12-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:15-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:18-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:22-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:25-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:28-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:32-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:35-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:39-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:42-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:45-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:49-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:52-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:56-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:22:59-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:23:02-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:23:06-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:23:09-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:23:26-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:23:43-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:24:00-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:24:17-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:24:34-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:24:51-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:25:08-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:25:30-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:25:48-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.apply_flags()
# HISTORY 2025-05-27T12:25:48-0400 - DYSH v0.6.1 : dysh.spectra.scan.ScanBlock.__i
# HISTORY nit__()
# HISTORY 2025-05-27T12:26:01-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# HISTORY ad.getnod(scan=[131, 133, 135, 137, 139],ifnum=1,plnum=1,t_sys=[[133.052
# HISTORY 86028258655], [82.88019155983231]],zenith_opacity=0.0599070412,bunit=Ta*
# HISTORY ,)
# HISTORY 2025-05-27T12:26:03-0400 - DYSH v0.6.1 : dysh.spectra.scan.ScanBlock.tim
# HISTORY eaverage()
# HISTORY 2025-05-27T12:26:03-0400 - DYSH v0.6.1 : dysh.spectra.spectrum.Spectrum.
# HISTORY __init__(flux=[          0.25915913  0.13702552 ...  0.13708298  0.09513
# HISTORY 163  -0.98704046] K,wcs=WCS Keywords  Number of WCS axes: 4 CTYPE : 'FRE
# HISTORY Q' 'RA' 'DEC' 'STOKES'  CRVAL : 87228489084.0 148.9319103755264 69.62197
# HISTORY 749862513 -5.0  CRPIX : 8193.0 0.0 0.0 0.0  PC1_1 PC1_2 PC1_3 PC1_4  : 1
# HISTORY .0 0.0 0.0 0.0  PC2_1 PC2_2 PC2_3 PC2_4  : 0.0 1.0 0.0 0.0  PC3_1 PC3_2
# HISTORY PC3_3 PC3_4  : 0.0 0.0 1.0 0.0  PC4_1 PC4_2 PC4_3 PC4_4  : 0.0 0.0 0.0 1
# HISTORY .0  CDELT : 91552.734375 1.0 1.0 1.0  NAXIS : 16384  0  0  0,meta={'OBJE
# HISTORY CT': 'M82', 'BANDWID': 1500000000.0, 'DATE-OBS': '2017-02-04T10:11:43.00
# HISTORY ', 'DURATION': 0.99964243, 'EXPOSURE': 298.3271931597574, 'TSYS': 96.905
# HISTORY 90086540854, 'TDIM7': '(16384,1,1,1)', 'TUNIT7': 'K', 'CTYPE1': 'FREQ-OB
# HISTORY S', 'CRVAL1': 87228489084.0, 'CRPIX1': 8193.0, 'CDELT1': 91552.734375, '
# HISTORY CTYPE2': 'RA', 'CRVAL2': 148.9319103755264, 'CTYPE3': 'DEC', 'CRVAL3': 6
# HISTORY 9.62197749862513, 'CRVAL4': -5, 'OBSERVER': 'Dom Pesce', 'OBSID': 'unkno
# HISTORY wn', 'SCAN': 131, 'OBSMODE': 'Nod:NONE:TPNOCAL', 'FRONTEND': 'Rcvr68_92'
# HISTORY , 'TCAL': 1.0, 'VELDEF': 'OPTI-BAR', 'VFRAME': 5241.161782043649, 'RVSYS
# HISTORY ': 5241.161782043649, 'OBSFREQ': 87228489084.0, 'LST': 49886.57916905915
# HISTORY , 'AZIMUTH': 334.4132429832569, 'ELEVATIO': 46.497692750558066, 'TAMBIEN
# HISTORY T': 261.45, 'PRESSURE': 699.2300098716685, 'HUMIDITY': 0.691, 'RESTFREQ'
# HISTORY : 87230000000.0, 'FREQRES': 91552.734375, 'EQUINOX': 2000.0, 'RADESYS':
# HISTORY 'FK5', 'TRGTLONG': 148.9695833333333, 'TRGTLAT': 69.67944444444444, 'SAM
# HISTORY PLER': 'B1_0', 'FEED': 1, 'SRFEED': 0, 'FEEDXOFF': 0.0, 'FEEDEOFF': 0.0,
# HISTORY  'SUBREF_STATE': 1, 'SIDEBAND': 'U', 'PROCSEQN': 1, 'PROCSIZE': 2, 'PROC
# HISTORY SCAN': 'BEAM1', 'PROCTYPE': 'SIMPLE', 'LASTON': 131, 'LASTOFF': 0, 'TIME
# HISTORY STAMP': '2017_02_04_10:11:43', 'QD_XEL': -0.0017257548370722825, 'QD_EL'
# HISTORY : 0.001033652915095047, 'QD_BAD': 0, 'QD_METHOD': 'A', 'VELOCITY': 0.0,
# HISTORY 'DOPFREQ': 86400000000.0, 'ADCSAMPF': 3000000000.0, 'VSPDELT': 512.0, 'V
# HISTORY SPRVAL': 16.0, 'VSPRPIX': 8193.0, 'SIG': 'T', 'CAL': 'F', 'CALTYPE': 'LO
# HISTORY W', 'TWARM': 263.18359375, 'TCOLD': 18.5546875, 'CALPOSITION': 'Observin
# HISTORY g', 'IFNUM': 1, 'PLNUM': 1, 'FDNUM': 0, 'HDU': 1, 'BINTABLE': 0, 'ROW':
# HISTORY 82, 'SIMPLE': True, 'EXTEND': True, 'DATE': '2024-07-12T13:16:23', 'ORIG
# HISTORY IN': 'NRAO Green Bank', 'TELESCOP': 'NRAO_GBT', 'INSTRUME': 'VEGAS', 'SD
# HISTORY FITVER': 'sdfits ver1.22', 'FITSVER': '1.9', 'CTYPE4': 'STOKES', 'PROJID
# HISTORY ': 'AGBT15B_244_07', 'BACKEND': 'VEGAS', 'SITELONG': -79.83983, 'SITELAT
# HISTORY ': 38.43312, 'SITEELEV': 824.595, 'EXTNAME': 'SINGLE DISH', 'FITSINDEX':
# HISTORY  1, 'PROC': 'Nod', 'OBSTYPE': 'NONE', 'SUBOBSMODE': 'TPNOCAL', 'CUNIT1':
# HISTORY  'Hz', 'CUNIT2': 'deg', 'CUNIT3': 'deg', 'RESTFRQ': 87230000000.0, 'BUNI
# HISTORY T': 'K', 'NAXIS1': 16384, 'MEANTSYS': 133.05286028258655, 'WTTSYS': 133.
# HISTORY 05286028258655},velocity_convention=optical,radial_velocity=0.0 km / s,r
# HISTORY est_value=87230000000.0 Hz,observer=<ITRS Coordinate (obstime=2017-02-04
# HISTORY T10:11:43.000, location=(0., 0., 0.) km): (x, y, z) in m     (882593.946
# HISTORY 5029, -4924896.36541728, 3943748.74743984)  (v_x, v_y, v_z) in km / s
# HISTORY   (0., 0., 0.)>,target=<SkyCoord (FK5: equinox=J2000.000): (ra, dec, dis
# HISTORY tance) in (deg, deg, kpc)     (148.93191038, 69.6219775, 1000000.)  (pm_
# HISTORY ra_cosdec, pm_dec, radial_velocity) in (mas / yr, mas / yr, km / s)
# HISTORY (0., 0., 0.)>,mask=[ True False False ... False False False],)
# HISTORY 2025-05-27T12:27:53-0400 - DYSH v0.6.1 : dysh.spectra.spectrum.Spectrum.
# HISTORY baseline(15,model=poly,exclude=[(<Quantity 86.47848908 GHz>, <Quantity 8
# HISTORY 6.52426545 GHz>), (<Quantity 87.2 GHz>, <Quantity 87.3 GHz>), (<Quantity
# HISTORY  87.93271272 GHz>, <Quantity 87.97839753 GHz>)],remove=True,)
# HISTORY 2025-05-27T12:27:56-0400 - DYSH v0.6.1 : dysh.spectra.spectrum.Spectrum.
# HISTORY __init__(flux=[         -0.40143808 -0.44712069 ...  0.2668698   0.24781
# HISTORY 759  -0.25501915] K,wcs=WCS Keywords  Number of WCS axes: 4 CTYPE : 'FRE
# HISTORY Q' 'RA' 'DEC' 'STOKES'  CRVAL : 87228489084.0 148.93912370729376 69.6332
# HISTORY 2331544632 -6.0  CRPIX : 8193.0 0.0 0.0 0.0  PC1_1 PC1_2 PC1_3 PC1_4  :
# HISTORY 1.0 0.0 0.0 0.0  PC2_1 PC2_2 PC2_3 PC2_4  : 0.0 1.0 0.0 0.0  PC3_1 PC3_2
# HISTORY  PC3_3 PC3_4  : 0.0 0.0 1.0 0.0  PC4_1 PC4_2 PC4_3 PC4_4  : 0.0 0.0 0.0
# HISTORY 1.0  CDELT : 91552.734375 1.0 1.0 1.0  NAXIS : 16384  0  0  0,meta={'OBJ
# HISTORY ECT': 'M82', 'BANDWID': 1500000000.0, 'DATE-OBS': '2017-02-04T10:11:43.0
# HISTORY 0', 'DURATION': 0.99964243, 'EXPOSURE': 596.6543863195149, 'TSYS': 105.2
# HISTORY 230347369145, 'TDIM7': '(16384,1,1,1)', 'TUNIT7': 'K', 'CTYPE1': 'FREQ-O
# HISTORY BS', 'CRVAL1': 87228489084.0, 'CRPIX1': 8193.0, 'CDELT1': 91552.734375,
# HISTORY 'CTYPE2': 'RA', 'CRVAL2': 148.93912370729376, 'CTYPE3': 'DEC', 'CRVAL3':
# HISTORY  69.63322331544632, 'CRVAL4': -6, 'OBSERVER': 'Dom Pesce', 'OBSID': 'unk
# HISTORY nown', 'SCAN': 131, 'OBSMODE': 'Nod:NONE:TPNOCAL', 'FRONTEND': 'Rcvr68_9
# HISTORY 2', 'TCAL': 1.0, 'VELDEF': 'OPTI-BAR', 'VFRAME': 5241.161782043649, 'RVS
# HISTORY YS': 5241.161782043649, 'OBSFREQ': 87228489084.0, 'LST': 49886.579169059
# HISTORY 15, 'AZIMUTH': 334.4132429832569, 'ELEVATIO': 46.497692750558066, 'TAMBI
# HISTORY ENT': 261.45, 'PRESSURE': 699.2300098716685, 'HUMIDITY': 0.691, 'RESTFRE
# HISTORY Q': 87230000000.0, 'FREQRES': 91552.734375, 'EQUINOX': 2000.0, 'RADESYS'
# HISTORY : 'FK5', 'TRGTLONG': 148.9695833333333, 'TRGTLAT': 69.67944444444444, 'S
# HISTORY AMPLER': 'B2_0', 'FEED': 1, 'SRFEED': 0, 'FEEDXOFF': 0.0, 'FEEDEOFF': 0.
# HISTORY 0, 'SUBREF_STATE': 1, 'SIDEBAND': 'U', 'PROCSEQN': 1, 'PROCSIZE': 2, 'PR
# HISTORY OCSCAN': 'BEAM1', 'PROCTYPE': 'SIMPLE', 'LASTON': 131, 'LASTOFF': 0, 'TI
# HISTORY MESTAMP': '2017_02_04_10:11:43', 'QD_XEL': -0.0017257548370722825, 'QD_E
# HISTORY L': 0.001033652915095047, 'QD_BAD': 0, 'QD_METHOD': 'A', 'VELOCITY': 0.0
# HISTORY , 'DOPFREQ': 86400000000.0, 'ADCSAMPF': 3000000000.0, 'VSPDELT': 512.0,
# HISTORY 'VSPRVAL': 16.0, 'VSPRPIX': 8193.0, 'SIG': 'T', 'CAL': 'F', 'CALTYPE': '
# HISTORY LOW', 'TWARM': 263.18359375, 'TCOLD': 18.5546875, 'CALPOSITION': 'Observ
# HISTORY ing', 'IFNUM': 1, 'PLNUM': 0, 'FDNUM': 0, 'HDU': 1, 'BINTABLE': 0, 'ROW'
# HISTORY : 83, 'SIMPLE': True, 'EXTEND': True, 'DATE': '2024-07-12T13:16:23', 'OR
# HISTORY IGIN': 'NRAO Green Bank', 'TELESCOP': 'NRAO_GBT', 'INSTRUME': 'VEGAS', '
# HISTORY SDFITVER': 'sdfits ver1.22', 'FITSVER': '1.9', 'CTYPE4': 'STOKES', 'PROJ
# HISTORY ID': 'AGBT15B_244_07', 'BACKEND': 'VEGAS', 'SITELONG': -79.83983, 'SITEL
# HISTORY AT': 38.43312, 'SITEELEV': 824.595, 'EXTNAME': 'SINGLE DISH', 'FITSINDEX
# HISTORY ': 1, 'PROC': 'Nod', 'OBSTYPE': 'NONE', 'SUBOBSMODE': 'TPNOCAL', 'CUNIT1
# HISTORY ': 'Hz', 'CUNIT2': 'deg', 'CUNIT3': 'deg', 'RESTFRQ': 87230000000.0, 'BU
# HISTORY NIT': 'K', 'NAXIS1': 16384, 'MEANTSYS': 105.01744133557179, 'WTTSYS': 10
# HISTORY 5.0174413355718},velocity_convention=optical,radial_velocity=0.0 km / s,
# HISTORY rest_value=87230000000.0 Hz,observer=<ITRS Coordinate (obstime=2017-02-0
# HISTORY 4T10:11:43.000, location=(0., 0., 0.) km): (x, y, z) in m     (882593.94
# HISTORY 65029, -4924896.36541728, 3943748.74743984)  (v_x, v_y, v_z) in km / s
# HISTORY    (0., 0., 0.)>,target=<SkyCoord (FK5: equinox=J2000.000): (ra, dec, di
# HISTORY stance) in (deg, deg, kpc)     (148.93912371, 69.63322332, 1000000.)  (p
# HISTORY m_ra_cosdec, pm_dec, radial_velocity) in (mas / yr, mas / yr, km / s)
# HISTORY   (0., 0., 0.)>,mask=[ True False False ... False False False],)
# HISTORY 2025-05-27T12:27:56-0400 - DYSH v0.6.1 : dysh.spectra.spectrum.Spectrum.
# HISTORY average(Spectrum1D (length=16384) Flux=[-0.74126516 -0.81091402 -0.74469
# HISTORY 508 ...  0.2672359   0.27843322        0.62303852] K,  mean=-0.00003 K S
# HISTORY pectral Axis=[8.64784891e+10 8.64785806e+10 8.64786722e+10 ...
# HISTORY       8.79782144e+10 8.79783060e+10 8.79783975e+10] Hz,  mean=8722844330
# HISTORY 7.63281 Hz,)
# COMMENT --BEGIN-ASTROPY-SERIALIZED-COLUMNS--
# COMMENT datatype:
# COMMENT - {name: spectral_axis, unit: Hz, datatype: float64, description: Spec\
# COMMENT tral axis}
# COMMENT - {name: flux, unit: K, datatype: float64, description: Flux}
# COMMENT - {name: uncertainty, datatype: float64, description: Flux uncertainty\
# COMMENT  (was not defined)}
# COMMENT - {name: weight, datatype: float64, description: Channel weights}
# COMMENT - {name: mask, datatype: int64, description: 'Mask 0=unmasked, 1=maske\
# COMMENT d'}
# COMMENT - {name: baseline, unit: K, datatype: float64, description: Fitted bas\
# COMMENT eline value at given channel (was not defined)}
# COMMENT meta:
# COMMENT   __serialized_columns__: {}
# COMMENT --END-ASTROPY-SERIALIZED-COLUMNS--

# %%
header["HISTORY"]
# Out:
# 2025-05-27T12:17:35 - This GBTFITSLoad encapsulates the files: ['data/AG
# BT15B_244_07.raw.vegas/AGBT15B_244_07.raw.vegas.A.fits', 'data/AGBT15B_2
# 44_07.raw.vegas/AGBT15B_244_07.raw.vegas.B.fits', 'data/AGBT15B_244_07.r
# aw.vegas/AGBT15B_244_07.raw.vegas.C.fits', 'data/AGBT15B_244_07.raw.vega
# s/AGBT15B_244_07.raw.vegas.D.fits', 'data/AGBT15B_244_07.raw.vegas/AGBT1
# 5B_244_07.raw.vegas.E.fits', 'data/AGBT15B_244_07.raw.vegas/AGBT15B_244_
# 07.raw.vegas.F.fits', 'data/AGBT15B_244_07.raw.vegas/AGBT15B_244_07.raw.
# vegas.G.fits', 'data/AGBT15B_244_07.raw.vegas/AGBT15B_244_07.raw.vegas.H
# .fits']
# 2025-05-27T12:17:40 - Project ID: AGBT15B_244_07
# 2025-05-27T12:17:40-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.__init__(./data/AGBT15B_244_07.raw.vegas,)
# 2025-05-27T12:17:44-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:17:48-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:17:51-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:17:55-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:17:58-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:02-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:05-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:08-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:12-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:15-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:19-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:22-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:25-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:29-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:32-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:35-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:39-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:42-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:45-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:49-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:52-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:55-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:18:59-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:02-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:05-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:09-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:12-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:16-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:19-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:22-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:26-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:29-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:32-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:36-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:39-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:43-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:46-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:49-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:53-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:56-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:19:59-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:03-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:06-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:09-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:13-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:16-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:20-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:23-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:26-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:30-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:33-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:36-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:40-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:43-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:46-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:50-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:53-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:20:56-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:00-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:03-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:07-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:10-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:13-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:17-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:20-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:24-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:27-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:31-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:34-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:38-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:41-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:45-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:48-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:51-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:55-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:21:58-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:01-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:05-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:08-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:12-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:15-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:18-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:22-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:25-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:28-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:32-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:35-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:39-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:42-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:45-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:49-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:52-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:56-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:22:59-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:23:02-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:23:06-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:23:09-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:23:26-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:23:43-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:24:00-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:24:17-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:24:34-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:24:51-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:25:08-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:25:30-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:25:48-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.apply_flags()
# 2025-05-27T12:25:48-0400 - DYSH v0.6.1 : dysh.spectra.scan.ScanBlock.__i
# nit__()
# 2025-05-27T12:26:01-0400 - DYSH v0.6.1 : dysh.fits.gbtfitsload.GBTFITSLo
# ad.getnod(scan=[131, 133, 135, 137, 139],ifnum=1,plnum=1,t_sys=[[133.052
# 86028258655], [82.88019155983231]],zenith_opacity=0.0599070412,bunit=Ta*
# ,)
# 2025-05-27T12:26:03-0400 - DYSH v0.6.1 : dysh.spectra.scan.ScanBlock.tim
# eaverage()
# 2025-05-27T12:26:03-0400 - DYSH v0.6.1 : dysh.spectra.spectrum.Spectrum.
# __init__(flux=[          0.25915913  0.13702552 ...  0.13708298  0.09513
# 163  -0.98704046] K,wcs=WCS Keywords  Number of WCS axes: 4 CTYPE : 'FRE
# Q' 'RA' 'DEC' 'STOKES'  CRVAL : 87228489084.0 148.9319103755264 69.62197
# 749862513 -5.0  CRPIX : 8193.0 0.0 0.0 0.0  PC1_1 PC1_2 PC1_3 PC1_4  : 1
# .0 0.0 0.0 0.0  PC2_1 PC2_2 PC2_3 PC2_4  : 0.0 1.0 0.0 0.0  PC3_1 PC3_2
# PC3_3 PC3_4  : 0.0 0.0 1.0 0.0  PC4_1 PC4_2 PC4_3 PC4_4  : 0.0 0.0 0.0 1
# .0  CDELT : 91552.734375 1.0 1.0 1.0  NAXIS : 16384  0  0  0,meta={'OBJE
# CT': 'M82', 'BANDWID': 1500000000.0, 'DATE-OBS': '2017-02-04T10:11:43.00
# ', 'DURATION': 0.99964243, 'EXPOSURE': 298.3271931597574, 'TSYS': 96.905
# 90086540854, 'TDIM7': '(16384,1,1,1)', 'TUNIT7': 'K', 'CTYPE1': 'FREQ-OB
# S', 'CRVAL1': 87228489084.0, 'CRPIX1': 8193.0, 'CDELT1': 91552.734375, '
# CTYPE2': 'RA', 'CRVAL2': 148.9319103755264, 'CTYPE3': 'DEC', 'CRVAL3': 6
# 9.62197749862513, 'CRVAL4': -5, 'OBSERVER': 'Dom Pesce', 'OBSID': 'unkno
# wn', 'SCAN': 131, 'OBSMODE': 'Nod:NONE:TPNOCAL', 'FRONTEND': 'Rcvr68_92'
# , 'TCAL': 1.0, 'VELDEF': 'OPTI-BAR', 'VFRAME': 5241.161782043649, 'RVSYS
# ': 5241.161782043649, 'OBSFREQ': 87228489084.0, 'LST': 49886.57916905915
# , 'AZIMUTH': 334.4132429832569, 'ELEVATIO': 46.497692750558066, 'TAMBIEN
# T': 261.45, 'PRESSURE': 699.2300098716685, 'HUMIDITY': 0.691, 'RESTFREQ'
# : 87230000000.0, 'FREQRES': 91552.734375, 'EQUINOX': 2000.0, 'RADESYS':
# 'FK5', 'TRGTLONG': 148.9695833333333, 'TRGTLAT': 69.67944444444444, 'SAM
# PLER': 'B1_0', 'FEED': 1, 'SRFEED': 0, 'FEEDXOFF': 0.0, 'FEEDEOFF': 0.0,
#  'SUBREF_STATE': 1, 'SIDEBAND': 'U', 'PROCSEQN': 1, 'PROCSIZE': 2, 'PROC
# SCAN': 'BEAM1', 'PROCTYPE': 'SIMPLE', 'LASTON': 131, 'LASTOFF': 0, 'TIME
# STAMP': '2017_02_04_10:11:43', 'QD_XEL': -0.0017257548370722825, 'QD_EL'
# : 0.001033652915095047, 'QD_BAD': 0, 'QD_METHOD': 'A', 'VELOCITY': 0.0,
# 'DOPFREQ': 86400000000.0, 'ADCSAMPF': 3000000000.0, 'VSPDELT': 512.0, 'V
# SPRVAL': 16.0, 'VSPRPIX': 8193.0, 'SIG': 'T', 'CAL': 'F', 'CALTYPE': 'LO
# W', 'TWARM': 263.18359375, 'TCOLD': 18.5546875, 'CALPOSITION': 'Observin
# g', 'IFNUM': 1, 'PLNUM': 1, 'FDNUM': 0, 'HDU': 1, 'BINTABLE': 0, 'ROW':
# 82, 'SIMPLE': True, 'EXTEND': True, 'DATE': '2024-07-12T13:16:23', 'ORIG
# IN': 'NRAO Green Bank', 'TELESCOP': 'NRAO_GBT', 'INSTRUME': 'VEGAS', 'SD
# FITVER': 'sdfits ver1.22', 'FITSVER': '1.9', 'CTYPE4': 'STOKES', 'PROJID
# ': 'AGBT15B_244_07', 'BACKEND': 'VEGAS', 'SITELONG': -79.83983, 'SITELAT
# ': 38.43312, 'SITEELEV': 824.595, 'EXTNAME': 'SINGLE DISH', 'FITSINDEX':
#  1, 'PROC': 'Nod', 'OBSTYPE': 'NONE', 'SUBOBSMODE': 'TPNOCAL', 'CUNIT1':
#  'Hz', 'CUNIT2': 'deg', 'CUNIT3': 'deg', 'RESTFRQ': 87230000000.0, 'BUNI
# T': 'K', 'NAXIS1': 16384, 'MEANTSYS': 133.05286028258655, 'WTTSYS': 133.
# 05286028258655},velocity_convention=optical,radial_velocity=0.0 km / s,r
# est_value=87230000000.0 Hz,observer=<ITRS Coordinate (obstime=2017-02-04
# T10:11:43.000, location=(0., 0., 0.) km): (x, y, z) in m     (882593.946
# 5029, -4924896.36541728, 3943748.74743984)  (v_x, v_y, v_z) in km / s
#   (0., 0., 0.)>,target=<SkyCoord (FK5: equinox=J2000.000): (ra, dec, dis
# tance) in (deg, deg, kpc)     (148.93191038, 69.6219775, 1000000.)  (pm_
# ra_cosdec, pm_dec, radial_velocity) in (mas / yr, mas / yr, km / s)
# (0., 0., 0.)>,mask=[ True False False ... False False False],)
# 2025-05-27T12:27:53-0400 - DYSH v0.6.1 : dysh.spectra.spectrum.Spectrum.
# baseline(15,model=poly,exclude=[(<Quantity 86.47848908 GHz>, <Quantity 8
# 6.52426545 GHz>), (<Quantity 87.2 GHz>, <Quantity 87.3 GHz>), (<Quantity
#  87.93271272 GHz>, <Quantity 87.97839753 GHz>)],remove=True,)
# 2025-05-27T12:27:56-0400 - DYSH v0.6.1 : dysh.spectra.spectrum.Spectrum.
# __init__(flux=[         -0.40143808 -0.44712069 ...  0.2668698   0.24781
# 759  -0.25501915] K,wcs=WCS Keywords  Number of WCS axes: 4 CTYPE : 'FRE
# Q' 'RA' 'DEC' 'STOKES'  CRVAL : 87228489084.0 148.93912370729376 69.6332
# 2331544632 -6.0  CRPIX : 8193.0 0.0 0.0 0.0  PC1_1 PC1_2 PC1_3 PC1_4  :
# 1.0 0.0 0.0 0.0  PC2_1 PC2_2 PC2_3 PC2_4  : 0.0 1.0 0.0 0.0  PC3_1 PC3_2
#  PC3_3 PC3_4  : 0.0 0.0 1.0 0.0  PC4_1 PC4_2 PC4_3 PC4_4  : 0.0 0.0 0.0
# 1.0  CDELT : 91552.734375 1.0 1.0 1.0  NAXIS : 16384  0  0  0,meta={'OBJ
# ECT': 'M82', 'BANDWID': 1500000000.0, 'DATE-OBS': '2017-02-04T10:11:43.0
# 0', 'DURATION': 0.99964243, 'EXPOSURE': 596.6543863195149, 'TSYS': 105.2
# 230347369145, 'TDIM7': '(16384,1,1,1)', 'TUNIT7': 'K', 'CTYPE1': 'FREQ-O
# BS', 'CRVAL1': 87228489084.0, 'CRPIX1': 8193.0, 'CDELT1': 91552.734375,
# 'CTYPE2': 'RA', 'CRVAL2': 148.93912370729376, 'CTYPE3': 'DEC', 'CRVAL3':
#  69.63322331544632, 'CRVAL4': -6, 'OBSERVER': 'Dom Pesce', 'OBSID': 'unk
# nown', 'SCAN': 131, 'OBSMODE': 'Nod:NONE:TPNOCAL', 'FRONTEND': 'Rcvr68_9
# 2', 'TCAL': 1.0, 'VELDEF': 'OPTI-BAR', 'VFRAME': 5241.161782043649, 'RVS
# YS': 5241.161782043649, 'OBSFREQ': 87228489084.0, 'LST': 49886.579169059
# 15, 'AZIMUTH': 334.4132429832569, 'ELEVATIO': 46.497692750558066, 'TAMBI
# ENT': 261.45, 'PRESSURE': 699.2300098716685, 'HUMIDITY': 0.691, 'RESTFRE
# Q': 87230000000.0, 'FREQRES': 91552.734375, 'EQUINOX': 2000.0, 'RADESYS'
# : 'FK5', 'TRGTLONG': 148.9695833333333, 'TRGTLAT': 69.67944444444444, 'S
# AMPLER': 'B2_0', 'FEED': 1, 'SRFEED': 0, 'FEEDXOFF': 0.0, 'FEEDEOFF': 0.
# 0, 'SUBREF_STATE': 1, 'SIDEBAND': 'U', 'PROCSEQN': 1, 'PROCSIZE': 2, 'PR
# OCSCAN': 'BEAM1', 'PROCTYPE': 'SIMPLE', 'LASTON': 131, 'LASTOFF': 0, 'TI
# MESTAMP': '2017_02_04_10:11:43', 'QD_XEL': -0.0017257548370722825, 'QD_E
# L': 0.001033652915095047, 'QD_BAD': 0, 'QD_METHOD': 'A', 'VELOCITY': 0.0
# , 'DOPFREQ': 86400000000.0, 'ADCSAMPF': 3000000000.0, 'VSPDELT': 512.0,
# 'VSPRVAL': 16.0, 'VSPRPIX': 8193.0, 'SIG': 'T', 'CAL': 'F', 'CALTYPE': '
# LOW', 'TWARM': 263.18359375, 'TCOLD': 18.5546875, 'CALPOSITION': 'Observ
# ing', 'IFNUM': 1, 'PLNUM': 0, 'FDNUM': 0, 'HDU': 1, 'BINTABLE': 0, 'ROW'
# : 83, 'SIMPLE': True, 'EXTEND': True, 'DATE': '2024-07-12T13:16:23', 'OR
# IGIN': 'NRAO Green Bank', 'TELESCOP': 'NRAO_GBT', 'INSTRUME': 'VEGAS', '
# SDFITVER': 'sdfits ver1.22', 'FITSVER': '1.9', 'CTYPE4': 'STOKES', 'PROJ
# ID': 'AGBT15B_244_07', 'BACKEND': 'VEGAS', 'SITELONG': -79.83983, 'SITEL
# AT': 38.43312, 'SITEELEV': 824.595, 'EXTNAME': 'SINGLE DISH', 'FITSINDEX
# ': 1, 'PROC': 'Nod', 'OBSTYPE': 'NONE', 'SUBOBSMODE': 'TPNOCAL', 'CUNIT1
# ': 'Hz', 'CUNIT2': 'deg', 'CUNIT3': 'deg', 'RESTFRQ': 87230000000.0, 'BU
# NIT': 'K', 'NAXIS1': 16384, 'MEANTSYS': 105.01744133557179, 'WTTSYS': 10
# 5.0174413355718},velocity_convention=optical,radial_velocity=0.0 km / s,
# rest_value=87230000000.0 Hz,observer=<ITRS Coordinate (obstime=2017-02-0
# 4T10:11:43.000, location=(0., 0., 0.) km): (x, y, z) in m     (882593.94
# 65029, -4924896.36541728, 3943748.74743984)  (v_x, v_y, v_z) in km / s
#    (0., 0., 0.)>,target=<SkyCoord (FK5: equinox=J2000.000): (ra, dec, di
# stance) in (deg, deg, kpc)     (148.93912371, 69.63322332, 1000000.)  (p
# m_ra_cosdec, pm_dec, radial_velocity) in (mas / yr, mas / yr, km / s)
#   (0., 0., 0.)>,mask=[ True False False ... False False False],)
# 2025-05-27T12:27:56-0400 - DYSH v0.6.1 : dysh.spectra.spectrum.Spectrum.
# average(Spectrum1D (length=16384) Flux=[-0.74126516 -0.81091402 -0.74469
# 508 ...  0.2672359   0.27843322        0.62303852] K,  mean=-0.00003 K S
# pectral Axis=[8.64784891e+10 8.64785806e+10 8.64786722e+10 ...
#       8.79782144e+10 8.79783060e+10 8.79783975e+10] Hz,  mean=8722844330
# 7.63281 Hz,)

# %% [markdown]
# The data table contains the spectral axis, flux, mask and other columns which are not used at the moment. For example, if we want to plot the data we can use the following

# %%
x = data["spectral_axis"]*1e-9 # Convert to GHz.
y = np.ma.masked_where(data["mask"], data["flux"]) # We need to mask the flux values.
plt.figure(dpi=150)
plt.plot(x, y)
plt.ylabel(r"$T_{A}^{*}$ (K)")
plt.xlabel(r"Frequency (GHz)");
